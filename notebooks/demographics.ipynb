# %% [markdown]
# # Demographics - Zürich area as a start
#
# ### Goal: Understand the demographics of the area, including population size, age distribution, income levels, household sizes, and nationalities. Target customer base should align with the local population.

# %%
import plotly.graph_objects as go
import plotly.express as px
import pandas as pd
import json

# %%
# Loading the data - downloaded from here: https://www.stadt-zuerich.ch/portal/de/index/ogd.html

population_2022 = pd.read_csv("../data/processed/zurich_population_2022.csv", delimiter=";").rename(columns={"Unnamed: 0": "Location"})
print(population_2022.head())

population_2030 = pd.read_csv("../data/processed/zurich_population_2030.csv", delimiter=";").rename(columns={"Unnamed: 0": "Location"})
print(population_2030.head())

population_2035 = pd.read_csv("../data/processed/zurich_population_2035.csv", delimiter=";").rename(columns={"Unnamed: 0": "Location"})
print(population_2035.head())
# Out:
#       Location     Total    0 – 9  10 – 19  20 – 29  30 – 39  40 – 49  \
# 0  Ganze Stadt   443 037   42 430   34 078   71 511   92 616   68 163
# 1      Kreis 1     5 860      252      321    1 193    1 155      753
# 2      Kreis 2    37 049    4 474    3 132    4 573    7 844    5 854
# 3  Wollishofen    20 570    2 562    1 559    2 403    4 399    3 368
# 4     Leimbach     6 462      828      836      732    1 036      935
#
#    50 – 59  60 – 69  70 – 79  80 – 89 90 – 99 100 und älter
# 0   52 771   35 600   25 922   15 579   4 272            95
# 1      771      612      506      245      51             1
# 2    4 276    2 841    2 179    1 401     456            19
# 3    2 323    1 672    1 215      795     262            12
# 4      779      534      421      283      76             2
#       Location     Total    0 – 9  10 – 19  20 – 29   30 – 39  40 – 49  \
# 0  Ganze Stadt   491 350   45 850   40 750   77 700   101 000   76 000
# 1      Kreis 1     5 900      300      300    1 150     1 300      800
# 2      Kreis 2    41 450    4 950    4 300    4 650     7 550    7 300
# 3  Wollishofen    23 250    2 850    2 450    2 150     4 000    4 350
# 4     Leimbach     7 500      900    1 000      950     1 100    1 150
#
#    50 – 59  60 – 69  70 – 79  80 – 89 90 – 99 100 und älter
# 0   57 500   42 500   27 500   17 400   5 000           150
# 1      600      650      450      350     100             –
# 2    4 850    3 450    2 250    1 600     550             –
# 3    2 800    1 950    1 350      950     300             –
# 4      850      700      450      300     100             –
#       Location     Total    0 – 9  10 – 19  20 – 29  30 – 39  40 – 49  \
# 0  Ganze Stadt   505 500   46 500   40 700   81 350   98 700   78 500
# 1      Kreis 1     5 950      300      300    1 150    1 300      850
# 2      Kreis 2    42 450    4 700    4 650    5 100    6 750    7 300
# 3  Wollishofen    23 650    2 550    2 750    2 450    3 250    4 300
# 4     Leimbach     7 850      900      950    1 000    1 150    1 200
#
#    50 – 59  60 – 69  70 – 79  80 – 89 90 – 99 100 und älter
# 0   60 900   44 050   30 800   18 050   5 750           200
# 1      600      550      450      300     100             –
# 2    5 650    3 600    2 550    1 600     600            50
# 3    3 400    2 050    1 550      950     350             –
# 4      950      750      500      300     100             –

# %%
pop_per_quarter = population_2030[["Location", "Total"]]
pop_per_quarter
# Out:
#                 Location     Total
# 0            Ganze Stadt   491 350
# 1                Kreis 1     5 900
# 2                Kreis 2    41 450
# 3            Wollishofen    23 250
# 4               Leimbach     7 500
# 5                   Enge    10 700
# 6                Kreis 3    55 400
# 7           Alt-Wiedikon    19 750
# 8            Friesenberg    12 900
# 9               Sihlfeld    22 750
# 10               Kreis 4    31 250
# 11                  Werd     4 800
# 12           Langstrasse    12 350
# 13                  Hard    14 100
# 14               Kreis 5    17 850
# 15         Gewerbeschule    10 100
# 16           Escher Wyss     7 800
# 17               Kreis 6    38 150
# 18           Unterstrass    26 800
# 19            Oberstrass    11 350
# 20               Kreis 7    42 750
# 21              Fluntern     9 550
# 22             Hottingen    12 050
# 23            Hirslanden     8 050
# 24               Witikon    13 100
# 25               Kreis 8    18 950
# 26               Seefeld     6 000
# 27             Mühlebach     6 750
# 28               Weinegg     6 250
# 29               Kreis 9    65 650
# 30           Albisrieden    25 850
# 31            Altstetten    39 800
# 32              Kreis 10    44 000
# 33                 Höngg    26 450
# 34             Wipkingen    17 550
# 35              Kreis 11    90 100
# 36             Affoltern    30 100
# 37              Oerlikon    26 950
# 38               Seebach    33 050
# 39              Kreis 12    39 950
# 40               Saatlen    10 600
# 41  Schwamendingen-Mitte    13 300
# 42            Hirzenbach    16 050

# %%
with open("../data/raw/stzh.adm_stadtkreise_a.json") as response:
    kreise = json.load(response)

with open("../data/raw/stzh.adm_verwaltungsquartiere_bes_p.json") as response:
    quarters = json.load(response)

print(quarters)

for i in quarters['features']:
    print(i['properties']['bezeichnung'])
    quarter = i['properties']['bezeichnung']
    pop = pop_per_quarter[pop_per_quarter['Location'] == quarter]
    print(pop)
# Out:
# {'type': 'FeatureCollection', 'name': 'stzh.adm_verwaltungsquartiere_bes_p', 'features': [{'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [8.5806097141, 47.3673800197]}, 'properties': {'objid': '1', 'bezeichnung': 'Hirslanden', 'kuerzel': '', 'ori': 0, 'hali': '1', 'vali': '2'}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [8.509313258, 47.3314802815]}, 'properties': {'objid': '2', 'bezeichnung': 'Leimbach', 'kuerzel': '', 'ori': 0, 'hali': '1', 'vali': '2'}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [8.5329555824, 47.3414911405]}, 'properties': {'objid': '3', 'bezeichnung': 'Wollishofen', 'kuerzel': '', 'ori': 0, 'hali': '1', 'vali': '2'}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [8.5331395744, 47.3609312211]}, 'properties': {'objid': '4', 'bezeichnung': 'Enge', 'kuerzel': '', 'ori': 0, 'hali': '1', 'vali': '2'}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [8.5562410091, 47.3545703201]}, 'properties': {'objid': '5', 'bezeichnung': 'Riesbach', 'kuerzel': '', 'ori': 0, 'hali': '1', 'vali': '2'}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [8.5092214171, 47.4232808331]}, 'properties': {'objid': '6', 'bezeichnung': 'Affoltern', 'kuerzel': '', 'ori': 0, 'hali': '1', 'vali': '2'}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [8.5428304697, 47.4236954049]}, 'properties': {'objid': '7', 'bezeichnung': 'Seebach', 'kuerzel': '', 'ori': 0, 'hali': '1', 'vali': '2'}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [8.5451168005, 47.4093482658]}, 'properties': {'objid': '8', 'bezeichnung': 'Oerlikon', 'kuerzel': '', 'ori': 0, 'hali': '1', 'vali': '2'}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [8.4964235871, 47.4079039826]}, 'properties': {'objid': '9', 'bezeichnung': 'HÃ¶ngg', 'kuerzel': '', 'ori': 0, 'hali': '1', 'vali': '2'}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [8.5395607892, 47.3983738799]}, 'properties': {'objid': '10', 'bezeichnung': 'Unterstrass', 'kuerzel': '', 'ori': 0, 'hali': '1', 'vali': '2'}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [8.5237542264, 47.3976900616]}, 'properties': {'objid': '11', 'bezeichnung': 'Wipkingen', 'kuerzel': '', 'ori': 0, 'hali': '1', 'vali': '2'}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [8.5734009465, 47.40278828]}, 'properties': {'objid': '12', 'bezeichnung': 'Schwamendingen', 'kuerzel': '', 'ori': 0, 'hali': '1', 'vali': '2'}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [8.5542342501, 47.3923039528]}, 'properties': {'objid': '13', 'bezeichnung': 'Oberstrass', 'kuerzel': '', 'ori': 0, 'hali': '1', 'vali': '2'}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [8.4814263642, 47.3897682867]}, 'properties': {'objid': '14', 'bezeichnung': 'Altstetten', 'kuerzel': '', 'ori': 0, 'hali': '1', 'vali': '2'}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [8.5232013806, 47.3785825655]}, 'properties': {'objid': '15', 'bezeichnung': 'Aussersihl', 'kuerzel': '', 'ori': 0, 'hali': '1', 'vali': '2'}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [8.5419914548, 47.3728336285]}, 'properties': {'objid': '16', 'bezeichnung': 'Altstadt', 'kuerzel': '', 'ori': 0, 'hali': '1', 'vali': '2'}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [8.5632757809, 47.38212986]}, 'properties': {'objid': '17', 'bezeichnung': 'Fluntern', 'kuerzel': '', 'ori': 0, 'hali': '1', 'vali': '2'}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [8.5830093981, 47.3790122757]}, 'properties': {'objid': '18', 'bezeichnung': 'Hottingen', 'kuerzel': '', 'ori': 0, 'hali': '1', 'vali': '2'}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [8.4842783217, 47.3705934339]}, 'properties': {'objid': '19', 'bezeichnung': 'Albisrieden', 'kuerzel': '', 'ori': 0,  ...
# Hirslanden
#       Location   Total
# 23  Hirslanden   8 050
# Leimbach
#    Location   Total
# 4  Leimbach   7 500
# Wollishofen
#       Location    Total
# 3  Wollishofen   23 250
# Enge
#   Location    Total
# 5     Enge   10 700
# Riesbach
# Empty DataFrame
# Columns: [Location, Total]
# Index: []
# Affoltern
#      Location    Total
# 36  Affoltern   30 100
# Seebach
#    Location    Total
# 38  Seebach   33 050
# Oerlikon
#     Location    Total
# 37  Oerlikon   26 950
# HÃ¶ngg
# Empty DataFrame
# Columns: [Location, Total]
# Index: []
# Unterstrass
#        Location    Total
# 18  Unterstrass   26 800
# Wipkingen
#      Location    Total
# 34  Wipkingen   17 550
# Schwamendingen
# Empty DataFrame
# Columns: [Location, Total]
# Index: []
# Oberstrass
#       Location    Total
# 19  Oberstrass   11 350
# Altstetten
#       Location    Total
# 31  Altstetten   39 800
# Aussersihl
# Empty DataFrame
# Columns: [Location, Total]
# Index: []
# Altstadt
# Empty DataFrame
# Columns: [Location, Total]
# Index: []
# Fluntern
#     Location   Total
# 21  Fluntern   9 550
# Hottingen
#      Location    Total
# 22  Hottingen   12 050
# Albisrieden
#        Location    Total
# 30  Albisrieden   25 850
# Wiedikon
# Empty DataFrame
# Columns: [Location, Total]
# Index: []
# Industriequartier
# Empty DataFrame
# Columns: [Location, Total]
# Index: []
# Witikon
#    Location    Total
# 24  Witikon   13 100

# %%
fig = px.choropleth_mapbox(
    dogs_per_kreis, 
    color="COUNT",
    geojson=kreise, 
    locations="STADTKREIS", 
    featureidkey="properties.name",
    center={"lat": 47.38, "lon": 8.54},
    mapbox_style="carto-positron", 
    zoom=10.8,
    opacity=0.7,
    width=700,
    height=600,
    labels={"STADTKREIS":"Kreis",
           "COUNT":"Number of Dogs"},
    title="<b>Number of Dogs per Kreis</b>",
    color_continuous_scale="Blues",
)
fig.update_layout(margin={"r":0,"t":35,"l":0,"b":0},
                  font_family="Balto",
                  font_color="black",
                  hoverlabel={"bgcolor":"white", 
                              "font_size":12,
                             "font_family":"Balto"},
                  title={"font_size":20,
                         "xanchor":"center", "x":0.38,
                        "yanchor":"bottom", "y":0.96}
                 )
fig.show()
